# %% [markdown]
# <a href="https://colab.research.google.com/github/hreczanyg/machine-learning-bootcamp/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install xlwt openpyxl xlrd

# %%
dane = pd.read_csv('/content/dane.csv', sep = ';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-21345b89d70d> in <cell line: 1>()
# ----> 1 dane = pd.read_csv('/content/dane.csv', sep = ';')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
dane[:4]

# %%
imionaM = pd.read_excel('/content/imiona_m.xlsx')
imiona_m = set(imionaM['imie_meskie'].str.capitalize())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf451626e6e8> in <cell line: 1>()
# ----> 1 imionaM = pd.read_excel('/content/imiona_m.xlsx')
#       2 imionaM = set(imionaM['imie_meskie'].str.capitalize())
#
# NameError: name 'pd' is not defined

# %%
imionaK = pd.read_excel('/content/imiona_k.xlsx')
polish_female_names = set(female_names_df['name'].str.capitalize())

# %%
def gender(first_name):
    if isinstance(first_name, str):
        if first_name in imionaK:
            return 'kobieta'
        elif first_name in imionaM:
            return 'mężczyzna'
        else:
          return None
    else: 
      return None

# %%
dane['gender'] = dane['first_name'].apply(gender)

# %%
dane
# Out:
#                  date_add first_name    last_name  \
# 0     2017-06-05 08:56:59   Waldemar     Hreczany
# 1     2017-07-12 05:39:26   Waldemar     Hreczany
# 2     2017-07-14 17:34:16    Dariusz  Kasprzyszak
# 3     2017-08-09 18:10:19      Beata          Koc
# 4     2017-08-30 20:34:21     Adrian    Olejarski
# ...                   ...        ...          ...
# 1299  2023-05-22 09:45:49   WERONIKA   STACHOWIAK
# 1300  2023-05-23 09:35:11        NaN          NaN
# 1301  2023-05-23 10:30:51     Jaklub      Stępień
# 1302  2023-05-28 16:25:07     Miłosz       Zwolak
# 1303  2023-05-28 19:52:37    Dariusz     Lindecki
#
#                                    email  registered           last_visit  \
# 0     waldemar.hreczany@poczta-polska.pl           0  0000-00-00 00:00:00
# 1                         waldekh3@wp.pl           1  0000-00-00 00:00:00
# 2                        darkov.85@wp.pl           0  0000-00-00 00:00:00
# ...
